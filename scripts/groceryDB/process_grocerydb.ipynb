# %%
from dsc80_utils import *

# %%
cols = [
    # 'original_ID',
    'name',
    'store',
    'harmonized single category',
    'brand',
    'f_FPro',
    # 'f_FPro_P',
    # 'f_min_FPro',
    # 'f_std_FPro',
    'f_FPro_class',
    'price',
    'price percal',
    'package_weight',
    'has10_nuts',
    'is_Nuts_Converted_100g',
    'Protein',
    'Total Fat',
    'Carbohydrate',
    'Sugars, total',
    'Fiber, total dietary',
    # 'Calcium',
    # 'Iron',
    'Sodium',
    # 'Vitamin C',
    'Cholesterol',
    # 'Fatty acids, total saturated',
    # 'Total Vitamin A',
]
col_renames = {
    'harmonized single category': 'category',
    'f_FPro': 'FPro',
    'f_FPro_class': 'FPro_class',
}

# %%
def subset_and_rename(df):
    return df[cols].rename(columns=col_renames)

# %%
def filter_has10(df):
    return (
        df.query('has10_nuts == 1 and is_Nuts_Converted_100g == 1')
        .drop(columns=['has10_nuts', 'is_Nuts_Converted_100g'])
    )

# %%
df = (
    pd.read_csv('GroceryDB_foods.csv')
    .pipe(subset_and_rename)
    .pipe(filter_has10)
)
df
# Out:
#                                                     name    store  \
# 0      Stonyfield Organic Whole Milk Strawberry Beet ...   Target
# 1      Stonyfield Organic Whole Milk Pear Spinach Man...   Target
# 2      Once Upon a Farm Organic Mama Blueberry Fruit ...   Target
# ...                                                  ...      ...
# 50464    Sabra Dark Chocolate Dessert Dip & Spread, 8 oz  Walmart
# 50465  MaraNatha, No Stir Peanut Butter, 1.15 oz Packets  Walmart
# 50466  Great Value No Stir Creamy Natural Peanut Butt...  Walmart
#
#              category             brand  ...  Sugars, total  \
# 0           baby-food        Stonyfield  ...           9.09
# 1           baby-food        Stonyfield  ...           9.09
# 2           baby-food  Once Upon a Farm  ...           7.69
# ...               ...               ...  ...            ...
# 50464  spread-squeeze             Sabra  ...          21.43
# 50465  spread-squeeze         MaraNatha  ...           3.12
# ...

# %%
display_df(df.describe(), rows=8, cols=12)
# Out:
#            FPro  FPro_class     price  price percal  package_weight   Protein  \
# count  26250.00    26250.00  22220.00      2.08e+04        24975.00  26250.00
# mean       0.73        2.48      4.64      3.00e-02          461.08      8.69
# std        0.23        1.03      3.73      3.53e-01         1934.76      8.96
# min        0.00        0.00      0.03      1.26e-05            0.53      0.00
# 25%        0.62        3.00      2.50      2.93e-03          198.45      2.92
# 50%        0.79        3.00      3.79      5.74e-03          336.00      6.67
# 75%        0.91        3.00      5.69      1.17e-02          473.00     11.76
# max        1.00        3.00     72.99      1.51e+01       272155.42    294.64
#
#        Total Fat  Carbohydrate  Sugars, total  Fiber, total dietary  \
# count   26250.00      26250.00       26241.00              26241.00
# mean       12.98         35.30          11.88                  3.23
# ...

# %%
df.to_csv('../../resources/data/grocerydb.csv', index=False)

# %%
display_df(df[df['name'].str.contains('Hapi')], cols=16)
# Out:
#                                        name       store  \
# 16992   Pure Punch Hapi Water 8ct, 48 fl oz  WholeFoods
# 34223           Hapi Hot Wasabi Peas 4.23oz      Target
# 45432  Hapi Snacks Wasabi Peas, Hot, 9.9 Oz     Walmart
# 45833              Hapi Sriracha Peas 9.9oz      Target
# 45834          Hapi Wasabi Green Peas 9.9oz      Target
#
#                       category        brand  FPro  FPro_class  price  \
# 16992  drink-soft-energy-mixes  HAPI DRINKS  0.88         3.0    NaN
# 34223         produce-packaged         Hapi  0.92         3.0   2.19
# 45432    snacks-mixes-crackers         Hapi  0.97         3.0   4.47
# 45833        snacks-nuts-seeds         Hapi  0.95         3.0   4.69
# 45834        snacks-nuts-seeds         Hapi  0.97         3.0   5.99
#
#        price percal  package_weight  Protein  Total Fat  Carbohydrate  \
# 16992           NaN         1440.00     0.00       0.00          2.78
# ...
